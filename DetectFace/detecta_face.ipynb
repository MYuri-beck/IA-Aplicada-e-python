# %%
import cv2
from skimage import io, color
from IPython.display import Image

# %%
Image(url="Imagens/faces.jpg")
# Out:
# <img src="Imagens/faces.jpg"/>

# %%
img_face1 = io.imread("Imagens/faces.jpg")
io.imshow(img_face1)
io.show()
# Out:
# C:\Users\Yuri\AppData\Local\Temp\ipykernel_31720\2691320439.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_face1)
# C:\Users\Yuri\AppData\Local\Temp\ipykernel_31720\2691320439.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
img_face1 = cv2.imread("Imagens/faces.jpg")
img_face1.shape
# Out:
# (630, 1000, 3)

# %%
img_face1_gray = color.rgb2gray(img_face1)
io.imshow(img_face1_gray)
io.show()
# Out:
# C:\Users\Yuri\AppData\Local\Temp\ipykernel_31720\2511867893.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.imshow(img_face1_gray)
# C:\Users\Yuri\AppData\Local\Temp\ipykernel_31720\2511867893.py:3: FutureWarning: `show` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   io.show()

# %%
img_face1_gray.shape
# Out:
# (630, 1000)

# %%
grayImage1 = cv2.cvtColor(img_face1, cv2.COLOR_BGR2GRAY)
grayImage1.shape
# Out:
# (630, 1000)

# %%
face_paramentro = "Cascade/frontalface_alt.xml"
classificador_cascade = cv2.CascadeClassifier(face_paramentro)

# %%
classificador_cascade
# Out:
# < cv2.CascadeClassifier 000002109B14C130>

# %%
faces = classificador_cascade.detectMultiScale(grayImage1, scaleFactor=1.2, minNeighbors=10, minSize=(30, 30))

# %%
faces
# Out:
# array([[294, 108,  46,  46],
#        [522, 113,  45,  45],
#        [801, 110,  49,  49],
#        [594, 114,  50,  50],
#        [847,  25,  51,  51],
#        [411, 100,  46,  46],
#        [100, 339,  52,  52],
#        [312,  24,  50,  50],
#        [760, 358,  49,  49],
#        [177, 121,  46,  46],
#        [305, 359,  58,  58],
#        [377,  36,  46,  46],
#        [847, 135,  49,  49],
#        [542,  45,  44,  44],
#        [616,  46,  43,  43],
#        [640, 380,  46,  46],
#        [226,  51,  47,  47],
#        [159,  48,  45,  45],
#        [562, 375,  46,  46],
#        [883, 373,  54,  54],
#        [388, 381,  51,  51],
#        [ 61,  67,  49,  49],
#        [679,  79,  48,  48]], dtype=int32)

# %%
for (x, y, whidth, height) in faces: 
    cv2.rectangle(img_face1, (x, y), (x + whidth, y + height), (0, 255, 0), 6)

# %%
cv2.imwrite("Imagens/faces_resultado.jpg", img_face1)
# Out:
# True

# %%
Image(url="Imagens/faces_resultado.jpg")
# Out:
# <img src="Imagens/faces_resultado.jpg"/>
